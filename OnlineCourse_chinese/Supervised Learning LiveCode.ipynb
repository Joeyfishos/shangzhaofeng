# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
# %matplotlib inline
from sklearn import datasets
from sklearn.datasets import load_boston

# %%
datasets.load_boston.data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-219-ee0998ec0d07> in <module>()
# ----> 1 datasets.load_boston.data
#
# AttributeError: 'function' object has no attribute 'data'

# %%
boston.display()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-215-03030fc7652a> in <module>()
# ----> 1 boston.display()
#
# AttributeError: 'function' object has no attribute 'display'

# %%
plt.hist(boston.target,bins=50)
plt.xlabel('prices')
plt.ylabel('NUMBer')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-211-3ffb00ef1200> in <module>()
# ----> 1 plt.hist(boston.target,bins=50)
#       2 plt.xlabel('prices')
#       3 plt.ylabel('NUMBer')
#
# AttributeError: 'function' object has no attribute 'target'

# %%
plt.scatter(boston.data[:,5],boston.target)

plt.ylabel('price')
plt.xlabel('NUber')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-195-b8242bd6311f> in <module>()
# ----> 1 plt.scatter(boston.data[:,5],boston.target)
#       2
#       3 plt.ylabel('price')
#       4 plt.xlabel('NUber')
#
# AttributeError: 'function' object has no attribute 'data'

# %%
boston.data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-216-813877612c4a> in <module>()
# ----> 1 boston.data
#
# AttributeError: 'function' object has no attribute 'data'

# %%
boston
# Out:
# <function sklearn.datasets.base.load_boston>

# %%
import seaborn as sns; sns.set(color_codes=True)
tips = sns.load_dataset("tips")
g = sns.lmplot(x="total_bill", y="tip", data=tips)

# %%
import seaborn as sns; sns.set(color_codes=True)
tips = sns.load_dataset("tips")
ax = sns.regplot(x="total_bill", y="tip", data=tips)

# %%
# regplot接受各种格式的x y，包括numpy arrays ,pandas series 或者pandas Dataframe对象。
# 相比之下,lmplot()只接受字符串对象。这种数据格式被称为’long-form’或者’tidy’。
# 除了输入数据的便利性外，regplot()可以看做拥有lmplot()特征的一个子集，所以接来下我们将用lmplot()进行演示。

# %%
s = pd.Series([1, 2, 3,4])

# %%
s.describe()
# Out:
# count    4.000000
# mean     2.500000
# std      1.290994
# min      1.000000
# 25%      1.750000
# 50%      2.500000
# 75%      3.250000
# max      4.000000
# dtype: float64
