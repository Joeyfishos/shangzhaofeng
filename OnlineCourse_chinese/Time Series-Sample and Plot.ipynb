# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import datetime

# %%
t_range=pd.date_range('20160101','20161231')

# %%
t_range
# Out:
# DatetimeIndex(['2016-01-01', '2016-01-02', '2016-01-03', '2016-01-04',
#                '2016-01-05', '2016-01-06', '2016-01-07', '2016-01-08',
#                '2016-01-09', '2016-01-10',
#                ...
#                '2016-12-22', '2016-12-23', '2016-12-24', '2016-12-25',
#                '2016-12-26', '2016-12-27', '2016-12-28', '2016-12-29',
#                '2016-12-30', '2016-12-31'],
#               dtype='datetime64[ns]', length=366, freq='D')

# %%
s= Series(np.random.rand(len(t_range)),index=t_range)

# %%
s.head()
# Out:
# 2016-01-01    0.193632
# 2016-01-02    0.368613
# 2016-01-03    0.794863
# 2016-01-04    0.557244
# 2016-01-05    0.609835
# Freq: D, dtype: float64

# %%
s['2016-01'].max()
# Out:
# 0.98821140987876566

# %% [markdown]
# # Sample

# %%
s_month=s.resample('M').mean()#必须要用mean()表示每个月拿个点，此为此月的平均

# %%
s_month
# Out:
# 2016-01-31    0.442614
# 2016-02-29    0.458256
# 2016-03-31    0.569047
# 2016-04-30    0.524082
# 2016-05-31    0.549174
# 2016-06-30    0.391089
# 2016-07-31    0.445914
# 2016-08-31    0.492926
# 2016-09-30    0.529794
# 2016-10-31    0.479250
# 2016-11-30    0.439263
# 2016-12-31    0.463172
# Freq: M, dtype: float64

# %%
s_hour=s.resample('H').bfill()

# %%
s_hour.head()
# Out:
# 2016-01-01 00:00:00    0.193632
# 2016-01-01 01:00:00    0.368613
# 2016-01-01 02:00:00    0.368613
# 2016-01-01 03:00:00    0.368613
# 2016-01-01 04:00:00    0.368613
# Freq: H, dtype: float64

# %%
s.plot()

# %%
# %matplotlib inline

# %%
s.plot()

# %%
s_month.plot()
