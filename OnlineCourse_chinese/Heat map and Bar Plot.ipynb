# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df= sns.load_dataset('flights')

# %%
df.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
df.plot()#默认为按照columns的折线图
plt.legend(loc=0)

# %%
df.plot(kind='bar')

# %%
df=df.pivot(index='month',columns='year',values='passengers')

# %%
df
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
df.plot()#画透视之后的折线图
plt.legend( bbox_to_anchor=(1.0,0.85),ncol=1)

# %%
df.plot(kind='bar')
# box = dd.get_position()
# dd.set_position([box.x0, box.y0, box.width , box.width* 1.9])
plt.legend( bbox_to_anchor=(1.0,0.85),ncol=1)
#调整图例

# %%
df.sum().plot(kind='bar')#matplotlib方法

# %%
sns.barplot(df.sum().index, df.sum().values)

# %%
df.sum().values
# Out:
# array([1520, 1676, 2042, 2364, 2700, 2867, 3408, 3939, 4421, 4572, 5140,
#        5714], dtype=int64)

# %%
sns.heatmap(df,cmap='Dark2')

# %%
sns.heatmap(df,annot=True,fmt='d')  # d  int   f  float

# %%
import matplotlib.pyplot as plt
figure,ax=plt.subplot(2,2)
x=[1,2]
y=[300,400]
ax[0][0].sns.barplot(x,y)

figure, ax=plt.subplots(2,2)#画一个22的子图的另一种方法
ax[0][0].plot(x,y1)
ax[0][0].plot(x,y2)
ax[1][1].plot(x,y2,'r--')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-79efe69a7b93> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 figure,ax=plt.subplot(2,2)
#       3 x=[1,2]
#       4 y=[300,400]
#       5 ax[0][0].sns.barplot(x,y)
#
# c:\users\zhaofeng shang\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1051
#    1052     fig = gcf()
# -> 1053     a = fig.add_subplot(*args, **kwargs)
#    1054     bbox = a.bbox
#    1055     byebye = []
#
# c:\users\zhaofeng shang\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1068                     self._axstack.remove(ax)
#    1069
# -> 1070             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1071
#    1072         self._axstack.add(key, a)
#
# ...
