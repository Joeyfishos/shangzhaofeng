# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=np.linspace(1,14,100)# 1-100等宽进行100个数。  第一个是1要分成100个 故 1+99x=14 就到了最后一位14了所以递增为0.1313.。
y1=np.sin(x)
y2=np.sin(2*x)

# %%
plt.plot(x,y1)
plt.plot(x,y2)

# %%
import seaborn as sns

# %%
sns.pointplot(x,y1)

# %% [markdown]
# # set_Style

# %%
sns.set_style('ticks')
#style must be one of white, dark, whitegrid, darkgrid, ticks

# %%
sns.pointplot(x,y1)

# %%
sns.set()#恢复到原始情形

# %% [markdown]
# # Set_context()

# %%
sns.set_context('notebook')
#paper, notebook, talk, poster

# %%
plt.plot(x,y2)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-76ae0518ec15> in <module>()
# ----> 1 sns.plotting.content()
#
# AttributeError: module 'seaborn' has no attribute 'plotting'
