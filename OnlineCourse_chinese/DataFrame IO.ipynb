# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
df = pd.read_clipboard()

# %%
df
# Out:
#   labels                                          message  length
# 0    ham  Go until jurong point, crazy.. Available only …     111
# 1    ham                        Ok lar… Joking wif u oni…      29
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina…     155
# 3    ham    U dun say so early hor… U c already then say…      49
# 4    ham  Nah I don’t think he goes to usf, he lives aro…      61

# %%
len('Ok lar sad fasdd')
# Out:
# 16

# %%
df.to_csv('df_ioi.csv',index=False)

# %%
pd.read_csv('df_io.csv')
# Out:
#     Unnamed: 0        Format     Type       Data     Description  Reader  \
# 0            0          text      CSV        NaN             NaN     NaN
# 1            1      read_csv      NaN        NaN             NaN     NaN
# 2            2        to_csv      NaN        NaN             NaN     NaN
# 3            3          text     JSON        NaN             NaN     NaN
# 4            4     read_json      NaN        NaN             NaN     NaN
# 5            5       to_json      NaN        NaN             NaN     NaN
# 6            6          text     HTML        NaN             NaN     NaN
# 7            7     read_html      NaN        NaN             NaN     NaN
# 8            8       to_html      NaN        NaN             NaN     NaN
# 9            9          text    Local  clipboard  read_clipboard     NaN
# 10          10  to_clipboard      NaN        NaN             NaN     NaN
# 11          11        binary       MS      Excel             NaN     NaN
# ...

# %%
df.to_json()
# Out:
# '{"bad_cases":{"0":"bad_cases"},"=":{"0":null},"origin_data_train.loc[origin_data_train[\'PassengerId\'].isin(split_cv[predictions":{"0":null},"!=":{"0":null},"cv_df.as_matrix()[:,0]][\'PassengerId\'].values)]":{"0":null}}'

# %%
df_json=df.to_json()

# %%
pd.read_json(df.to_json())
# Out:
#    !=   =  bad_cases  cv_df.as_matrix()[:,0]]['PassengerId'].values)]  \
# 0 NaN NaN  bad_cases                                              NaN
#
#    origin_data_train.loc[origin_data_train['PassengerId'].isin(split_cv[predictions
# 0                                                NaN

# %%
df.to_html('df_io.html')

# %%
df_html=pd.read_html('df_io.html')

# %%
dff=DataFrame({'A':[1,2,3],'B':[2,1,2],'C':[2,3,2]})
dff
# Out:
#    A  B  C
# 0  1  2  2
# 1  2  1  3
# 2  3  2  2

# %%
dff[dff['B']!=dff['C']][['C','B']]
# Out:
#    C  B
# 1  3  1

# %%
dff[dff['B']!=dff['C']]['C'].values
# Out:
# array([3], dtype=int64)

# %%
c=dff['C'].isin(dff[dff['B']!=dff['C']]['C'].values)
c
# Out:
# 0    False
# 1     True
# 2    False
# Name: C, dtype: bool

# %%
dff.loc[dff['C'].isin(dff['B']==dff['C'])]
# Out:
# Empty DataFrame
# Columns: [A, B, C]
# Index: []

# %%
bad_cases = origin_data_train.loc[origin_data_train['PassengerId'].isin(split_cv[predictions != cv_df.as_matrix()[:,0]]['PassengerId'].values)]
bad_cases
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-108-7e349dd26054> in <module>()
# ----> 1 bad_cases = origin_data_train.loc[origin_data_train['PassengerId'].isin(split_cv[predictions != cv_df.as_matrix()[:,0]]['PassengerId'].values)]
#       2 bad_cases
#
# NameError: name 'origin_data_train' is not defined
